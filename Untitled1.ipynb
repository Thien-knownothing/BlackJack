# %%
import random
play = True
suits = ['Hearts','Diamonds','Spades','Clubs']
ranks = ['Two','Three','Four','Five','Six','Seven','Eight','Night','Ten','Jack','Queen','King','Ace']
values ={'Two':2, 'Three':3, 'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':10,'Queen':10,'King':10,'Ace':11}

class Card:
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
    def  __str__(self):
        return self.rank +' of '+ self.suit
    
class Deck:
    def __init__(self):
        self.deck = []
        for suit in suits:
            for rank in ranks:
                    self.deck.append(Card(suit,rank))
    def __str__(self):
        all_card = ''
        for card in self.deck:
            all_card +='\n' +card.__str__()
        
        return all_card
    def shuffle(self):
        random.shuffle(self.deck)
    def deal(self):
        dealed = self.deck.pop()
        return dealed

class Hand:
    def __init__(self):
        self.cards = []
        self.value = 0
        self.aces = 0
    def add_card(self,card):
        self.cards.append(card)
        self.value += values[card.rank]
        if card.rank == 'Ace':
            self.aces +=1
    def adjust(self):
        while self.value >21 and self.aces:
            self.value -=10
            self.aces -=1

class Chips:
    def __init__(self):
        self.balance = 100
        self.bet = 0
    def loss(self):
        self.balance-=self.bet
    def win(self):
        self.balance +=self.bet
        
def take_bet(chips):
    while True:
        try: 
            chips.bet = int(input('Place your bet, must not exceed balance: '))
        except ValueError:
            print('thats not a number, again please!')
        else: 
            if chips.bet > chips.balance:
                print('baka')
            else:
                break


def hit(deck,hand):
    hand.add_card(deck.deal())
    hand.adjust()
    
def Hit_or_Stand(deck,hand):
    global play
    
    while True:
        hit_or_stand = input("Hit or Stand, please select H or S: ")
        
        if hit_or_stand[0].upper() == 'H':
            hit(deck,hand)
        
        elif hit_or_stand[0].upper() == 'S':
            play = False
            
        else:
            print('Thats a wrong input')
            continue
        break
def show_half(player,dealer):
    print('Dealer card is half hidden: ')
    print(dealer.cards[0])
    print('All player card is avaible to see:')
    for i in player.cards:
        print(i)

def show_all(player,dealer):
    print("All dealer's card is shown: ")
    for i in dealer.cards:
        print(i)
    print("All player's card is shown: ")
    for j in player.cards:
        print(j)

def player_bust(player_chips):
    print("Busted")
    player_chips.loss()

def dealer_win(player_chips):
    print("Dealer win, you lost your bet")
    player_chips.loss()

def player_win(player_chips):
    print("Player win, you win dealer bet")
    player_chips.win()
    
def dealer_bust(player_chips):
    print("Dealer is busted, player win")
    player_chips.win()

def push(player_chips):
    print("Draw")


    
while True:
    deck = Deck()
    deck.shuffle()
   
    player_card = Hand()
    player_card.add_card(deck.deal())
    player_card.add_card(deck.deal())
    dealer_card = Hand()
    dealer_card.add_card(deck.deal())
    dealer_card.add_card(deck.deal())
    player_chips = Chips()
    take_bet(player_chips)
    show_half(player_card,dealer_card)
    
    while play:
        Hit_or_Stand(deck,player_card)
        show_half(player_card,dealer_card)
        if player_card.value > 21:
            player_bust(player_chips)
            break
            
    if player_card.value <= 21:
        while dealer_card.value < 17:
            dealer_card.add_card(deck.deal())
        show_all(player_card,dealer_card)
        if dealer_card.value > 21:
            dealer_bust(player_chips)
        elif dealer_card.value > player_card.value:
            dealer_win(player_chips)
        elif dealer_card.value < player_card.value:
            player_win(player_chips)
        else:
            push()
    print("Your balance",player_chips.balance)
    newgame = input("New game?: Y/N")
    if newgame[0].upper() == "Y":
        play = True
        continue
    else: 
        print("Endgame")
        break
    
        

                
            

    
       

        
h
# Out:
# Place your bet, must not exceed balance: 70
# Dealer card is half hidden:
# Six of Diamonds
# All player card is avaible to see:
# Ten of Spades
# Five of Hearts
# Hit or Stand, please select H or S: h
# Dealer card is half hidden:
# Six of Diamonds
# All player card is avaible to see:
# Ten of Spades
# Five of Hearts
# Five of Clubs
# Hit or Stand, please select H or S: s
# Dealer card is half hidden:
# Six of Diamonds
# All player card is avaible to see:
# Ten of Spades
# Five of Hearts
# Five of Clubs
# All dealer's card is shown:
# Six of Diamonds
# Ten of Diamonds
# Queen of Spades
# All player's card is shown:
# Ten of Spades
# Five of Hearts
# Five of Clubs
# Dealer is busted, player win
# Your balance 170
# New game?: Y/Ny
# Place your bet, must not exceed balance: 50
# Dealer card is half hidden:
# Jack of Hearts
# All player card is avaible to see:
# Two of Spades
# Six of Clubs
# Hit or Stand, please select H or S: h
# Dealer card is half hidden:
# Jack of Hearts
# ...

# %%
testdeck = Deck()
testdeck.shuffle()
dealed = testdeck.deal()
testplayer = Hand()
testplayer.add_card(testdeck.deal())
testplayer.add_card(testdeck.deal())
for i in testplayer.cards:
    print(i)
print(testplayer.value)
chips = Chips()
take_bet(chips)
# Out:
# Seven of Clubs
# Queen of Hearts
# 17
# Place your bet, must not exceed balance: 500
# baka
# Place your bet, must not exceed balance: 500
# baka
# Place your bet, must not exceed balance: 50
# 50

# %%
for card in testplayer.cards:
    print(card.rank)

# %%
values[card.rank]
# Out:
# 7
